# %%
import pandas as pd

# %%
dataset=pd.read_csv("kidney_disease.csv")
dataset
# Out:
#       age    bp      sg   al        su         bgr    bu   sc         sod  \
# 0    48.0  80.0  1.0200  1.0  0.000000  121.000000  36.0  1.2  137.528754
# 1     9.0  55.0  1.0200  4.0  0.000000  148.036517  18.0  0.8  137.528754
# 2    62.0  80.0  1.0100  2.0  1.125356  223.500000  53.0  1.8  137.528754
# 3    48.0  70.0  1.0075  4.0  0.000000  117.000000  56.0  3.8  126.000000
# 4    51.0  80.0  1.0100  2.0  0.000000  106.000000  26.0  1.4  137.528754
# ..    ...   ...     ...  ...       ...         ...   ...  ...         ...
# 395  55.0  80.0  1.0200  0.0  0.000000  140.000000  49.0  0.5  150.000000
# 396  42.0  70.0  1.0250  0.0  0.000000   75.000000  31.0  1.2  141.000000
# 397  12.0  80.0  1.0200  0.0  0.000000  100.000000  26.0  0.6  137.000000
# 398  17.0  60.0  1.0250  0.0  0.000000  114.000000  50.0  1.0  135.000000
# 399  58.0  80.0  1.0250  0.0  0.000000  131.000000  18.0  1.1  141.000000
#
#           pot  ...  pcv    wc   rc  htn   dm cad appet   pe  ane  \
# ...

# %%
dataset.isnull()
# Out:
#        age     bp     sg     al     su    bgr     bu     sc    sod    pot  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 395  False  False  False  False  False  False  False  False  False  False
# 396  False  False  False  False  False  False  False  False  False  False
# 397  False  False  False  False  False  False  False  False  False  False
# 398  False  False  False  False  False  False  False  False  False  False
# 399  False  False  False  False  False  False  False  False  False  False
#
#      ...    pcv     wc     rc    htn     dm    cad  appet     pe    ane  \
# ...

# %%
dataset.isnull().sum()
# Out:
# age               0
# bp                0
# sg                0
# al                0
# su                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# rbc               0
# pc                0
# pcc               0
# ba                0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
#  Replace the missing value with central tendency-Mean Median Mode
#  Entire Row delete
#  Respective to the problem,have to replace the missing values
#  Consider this as a semi supervised, create a model, so  we can predict the missing values.

# %%
 #dataset.isnull().sum() and dataset.isna().sum()   both are same we can use anyone
    
dataset.isnull().sum()
# Out:
# age               0
# bp                0
# sg                0
# al                0
# su                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# rbc               0
# pc                0
# pcc               0
# ba                0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
dataset=pd.read_csv("kidney_disease.csv")
dataset
# Out:
#       age    bp      sg   al        su         bgr    bu   sc         sod  \
# 0    48.0  80.0  1.0200  1.0  0.000000  121.000000  36.0  1.2  137.528754
# 1     9.0  55.0  1.0200  4.0  0.000000  148.036517  18.0  0.8  137.528754
# 2    62.0  80.0  1.0100  2.0  1.125356  223.500000  53.0  1.8  137.528754
# 3    48.0  70.0  1.0075  4.0  0.000000  117.000000  56.0  3.8  126.000000
# 4    51.0  80.0  1.0100  2.0  0.000000  106.000000  26.0  1.4  137.528754
# ..    ...   ...     ...  ...       ...         ...   ...  ...         ...
# 395  55.0  80.0  1.0200  0.0  0.000000  140.000000  49.0  0.5  150.000000
# 396  42.0  70.0  1.0250  0.0  0.000000   75.000000  31.0  1.2  141.000000
# 397  12.0  80.0  1.0200  0.0  0.000000  100.000000  26.0  0.6  137.000000
# 398  17.0  60.0  1.0250  0.0  0.000000  114.000000  50.0  1.0  135.000000
# 399  58.0  80.0  1.0250  0.0  0.000000  131.000000  18.0  1.1  141.000000
#
#           pot  ...  pcv    wc   rc  htn   dm cad appet   pe  ane  \
# ...

# %%
dataset=pd.read_csv("kidney_disease.csv")
dataset
# Out:
#       age    bp      sg   al        su         bgr    bu   sc         sod  \
# 0    48.0  80.0  1.0200  1.0  0.000000  121.000000  36.0  1.2  137.528754
# 1     9.0  55.0  1.0200  4.0  0.000000  148.036517  18.0  0.8  137.528754
# 2    62.0  80.0  1.0100  2.0  1.125356  223.500000  53.0  1.8  137.528754
# 3    48.0  70.0  1.0075  4.0  0.000000  117.000000  56.0  3.8  126.000000
# 4    51.0  80.0  1.0100  2.0  0.000000  106.000000  26.0  1.4  137.528754
# ..    ...   ...     ...  ...       ...         ...   ...  ...         ...
# 395  55.0  80.0  1.0200  0.0  0.000000  140.000000  49.0  0.5  150.000000
# 396  42.0  70.0  1.0250  0.0  0.000000   75.000000  31.0  1.2  141.000000
# 397  12.0  80.0  1.0200  0.0  0.000000  100.000000  26.0  0.6  137.000000
# 398  17.0  60.0  1.0250  0.0  0.000000  114.000000  50.0  1.0  135.000000
# 399  58.0  80.0  1.0250  0.0  0.000000  131.000000  18.0  1.1  141.000000
#
#           pot  ...  pcv    wc   rc  htn   dm cad appet   pe  ane  \
# ...

# %%
def quanQual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        #print(columnName)
        if(dataset[columnName].dtype=='O'):
            #print("qual")
            qual.append(columnName)
        else:
            #print("quan")
            quan.append(columnName)
    return quan,qual

# %%
quan,qaul=quanQual(dataset)
dataset[quan]
# Out:
#       age    bp      sg   al        su         bgr    bu   sc         sod  \
# 0    48.0  80.0  1.0200  1.0  0.000000  121.000000  36.0  1.2  137.528754
# 1     9.0  55.0  1.0200  4.0  0.000000  148.036517  18.0  0.8  137.528754
# 2    62.0  80.0  1.0100  2.0  1.125356  223.500000  53.0  1.8  137.528754
# 3    48.0  70.0  1.0075  4.0  0.000000  117.000000  56.0  3.8  126.000000
# 4    51.0  80.0  1.0100  2.0  0.000000  106.000000  26.0  1.4  137.528754
# ..    ...   ...     ...  ...       ...         ...   ...  ...         ...
# 395  55.0  80.0  1.0200  0.0  0.000000  140.000000  49.0  0.5  150.000000
# 396  42.0  70.0  1.0250  0.0  0.000000   75.000000  31.0  1.2  141.000000
# 397  12.0  80.0  1.0200  0.0  0.000000  100.000000  26.0  0.6  137.000000
# 398  17.0  60.0  1.0250  0.0  0.000000  114.000000  50.0  1.0  135.000000
# 399  58.0  80.0  1.0250  0.0  0.000000  131.000000  18.0  1.1  141.000000
#
#           pot  hemo
# 0    4.627244  15.4
# 1    4.627244  11.3
# ...

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
df=imp.transform(dataset[quan])

# %%
df = pd.DataFrame(df,columns = quan)
df
# Out:
#       age    bp      sg   al        su         bgr    bu   sc         sod  \
# 0    48.0  80.0  1.0200  1.0  0.000000  121.000000  36.0  1.2  137.528754
# 1     9.0  55.0  1.0200  4.0  0.000000  148.036517  18.0  0.8  137.528754
# 2    62.0  80.0  1.0100  2.0  1.125356  223.500000  53.0  1.8  137.528754
# 3    48.0  70.0  1.0075  4.0  0.000000  117.000000  56.0  3.8  126.000000
# 4    51.0  80.0  1.0100  2.0  0.000000  106.000000  26.0  1.4  137.528754
# ..    ...   ...     ...  ...       ...         ...   ...  ...         ...
# 395  55.0  80.0  1.0200  0.0  0.000000  140.000000  49.0  0.5  150.000000
# 396  42.0  70.0  1.0250  0.0  0.000000   75.000000  31.0  1.2  141.000000
# 397  12.0  80.0  1.0200  0.0  0.000000  100.000000  26.0  0.6  137.000000
# 398  17.0  60.0  1.0250  0.0  0.000000  114.000000  50.0  1.0  135.000000
# 399  58.0  80.0  1.0250  0.0  0.000000  131.000000  18.0  1.1  141.000000
#
#           pot  hemo
# 0    4.627244  15.4
# 1    4.627244  11.3
# ...

# %%
cate=dataset[qaul]
cate
# Out:
#         rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0    normal    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1    normal    normal  notpresent  notpresent  38  6000  5.2   no   no  no
# 2    normal    normal  notpresent  notpresent  31  7500  5.2   no  yes  no
# 3    normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4    normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
# ..      ...       ...         ...         ...  ..   ...  ...  ...  ...  ..
# 395  normal    normal  notpresent  notpresent  47  6700  4.9   no   no  no
# 396  normal    normal  notpresent  notpresent  54  7800  6.2   no   no  no
# 397  normal    normal  notpresent  notpresent  49  6600  5.4   no   no  no
# 398  normal    normal  notpresent  notpresent  51  7200  5.9   no   no  no
# 399  normal    normal  notpresent  notpresent  53  6800  6.1   no   no  no
#
#     appet   pe  ane classification
# ...

# %%
two=[df,cate]

# %%
preprocessed=pd.concat(two,axis=1)
preprocessed
# Out:
#       age    bp      sg   al        su         bgr    bu   sc         sod  \
# 0    48.0  80.0  1.0200  1.0  0.000000  121.000000  36.0  1.2  137.528754
# 1     9.0  55.0  1.0200  4.0  0.000000  148.036517  18.0  0.8  137.528754
# 2    62.0  80.0  1.0100  2.0  1.125356  223.500000  53.0  1.8  137.528754
# 3    48.0  70.0  1.0075  4.0  0.000000  117.000000  56.0  3.8  126.000000
# 4    51.0  80.0  1.0100  2.0  0.000000  106.000000  26.0  1.4  137.528754
# ..    ...   ...     ...  ...       ...         ...   ...  ...         ...
# 395  55.0  80.0  1.0200  0.0  0.000000  140.000000  49.0  0.5  150.000000
# 396  42.0  70.0  1.0250  0.0  0.000000   75.000000  31.0  1.2  141.000000
# 397  12.0  80.0  1.0200  0.0  0.000000  100.000000  26.0  0.6  137.000000
# 398  17.0  60.0  1.0250  0.0  0.000000  114.000000  50.0  1.0  135.000000
# 399  58.0  80.0  1.0250  0.0  0.000000  131.000000  18.0  1.1  141.000000
#
#           pot  ...  pcv    wc   rc  htn   dm cad appet   pe  ane  \
# ...

# %%
preprocessed.isnull().sum()
# Out:
# age               0
# bp                0
# sg                0
# al                0
# su                0
# bgr               0
# bu                0
# sc                0
# sod               0
# pot               0
# hemo              0
# rbc               0
# pc                0
# pcc               0
# ba                0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
preprocessed.to_csv("Data_Preprocessed_for_kidney_disease.csv",index=False)
